# %%
import numpy as np
import matplotlib.pyplot as plt

mapfile = '../../maps/map_cloud.txt'
map = np.loadtxt(mapfile)
plt.imshow(map)

# %%
mapfile = '../../maps/map_cloud_house.txt'
map = np.loadtxt(mapfile)
plt.imshow(map)

# %%
mapfile = '../../maps/map_cloud_house_05.txt'
map = np.loadtxt(mapfile)
plt.imshow(map)

# %%
mapfile = '../../maps/map_cloud_marsyard2020_05.txt'
map = np.loadtxt(mapfile)
plt.imshow(map)
